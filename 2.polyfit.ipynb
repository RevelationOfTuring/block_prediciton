# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns;sns.set()
import matplotlib.pyplot as plt

# %%
# load data
hdf5=pd.HDFStore('data/block_data.h5','r')
training_data=hdf5['training_data']
test_data=hdf5['test_data']

# %%
# draw training data
threshold=30000000
training_data['gas_used'].plot(figsize=(50,20))
plt.axhline(threshold,color='r')

# %%
gas_used_training=training_data['gas_used'].values
block_height_training=np.asarray(training_data.index)

gas_used_test=test_data['gas_used'].values
block_height_test=np.asarray(test_data.index)

# %%
# focus!!
# linear regression
# 1次回归
rg1 = np.polyfit(block_height_training,gas_used_training,1)
plt.figure(figsize=(25,10))
plt.subplot(211)
training_data['gas_used'].plot()
plt.plot(block_height_training,np.polyval(rg1,block_height_training),'r',label='regression')
plt.legend()

# predict
plt.subplot(212)
test_data['gas_used'].plot()
plt.plot(block_height_test,np.polyval(rg1,block_height_test),'r',label='predict')
plt.legend()

print(rg1)
# Out:
# [-2.92988321e+01  1.81431944e+08]

# %%
# 2次回归
rg2 = np.polyfit(block_height_training,gas_used_training,2)
plt.figure(figsize=(25,10))
plt.subplot(211)
training_data['gas_used'].plot()
plt.plot(block_height_training,np.polyval(rg2,block_height_training),'r',label='regression')
plt.legend()

# predict
plt.subplot(212)
test_data['gas_used'].plot()
plt.plot(block_height_test,np.polyval(rg2,block_height_test),'r',label='predict')
plt.legend()

print(rg2)
# Out:
# [-1.59721189e-03  1.82675316e+04 -5.22176335e+10]

# %%
# 3次回归
rg3 = np.polyfit(block_height_training,gas_used_training,3)
plt.figure(figsize=(25,10))
plt.subplot(211)
training_data['gas_used'].plot()
plt.plot(block_height_training,np.polyval(rg3,block_height_training),'r',label='regression')
plt.legend()

# predict
plt.subplot(212)
test_data['gas_used'].plot()
plt.plot(block_height_test,np.polyval(rg3,block_height_test),'r',label='predict')
plt.legend()

print(rg3)
# Out:
# [ 4.87879874e-08 -8.39932006e-01  4.81999414e+06 -9.21975558e+12]

# %%
# 4次回归
rg4 = np.polyfit(block_height_training,gas_used_training,4)
plt.figure(figsize=(25,10))
plt.subplot(211)
training_data['gas_used'].plot()
plt.plot(block_height_training,np.polyval(rg4,block_height_training),'r',label='regression')
plt.legend()

# predict
plt.subplot(212)
test_data['gas_used'].plot()
plt.plot(block_height_test,np.polyval(rg4,block_height_test),'r',label='predict')
plt.legend()

print(rg4)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# [ 4.30418191e-15 -4.94246543e-08  4.28763416e-04  1.62425063e+06
#  -4.66254006e+12]

# %%
# 5次回归
rg5 = np.polyfit(block_height_training,gas_used_training,5)
plt.figure(figsize=(25,10))
plt.subplot(211)
training_data['gas_used'].plot()
plt.plot(block_height_training,np.polyval(rg5,block_height_training),'r',label='regression')
plt.legend()

# predict
plt.subplot(212)
test_data['gas_used'].plot()
plt.plot(block_height_test,np.polyval(rg5,block_height_test),'r',label='predict')
plt.legend()

print(rg5)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# [ 1.22960055e-18 -2.11242738e-11  8.06292784e-05  4.62114913e+02
#  -3.96860777e+09  7.57534949e+15]

# %%
# 6次回归
rg6 = np.polyfit(block_height_training,gas_used_training,6)
plt.figure(figsize=(25,10))
plt.subplot(211)
training_data['gas_used'].plot()
plt.plot(block_height_training,np.polyval(rg6,block_height_training),'r',label='regression')
plt.legend()

# predict
plt.subplot(212)
test_data['gas_used'].plot()
plt.plot(block_height_test,np.polyval(rg6,block_height_test),'r',label='predict')
plt.legend()

print(rg6)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# [ 1.17122997e-25 -1.56489350e-18  1.27719664e-12  4.40065077e-05
#   4.21032207e+01 -1.68421268e+09  4.13310976e+15]

# %%
# 7次回归
rg7 = np.polyfit(block_height_training,gas_used_training,7)
plt.figure(figsize=(25,10))
plt.subplot(211)
training_data['gas_used'].plot()
plt.plot(block_height_training,np.polyval(rg7,block_height_training),'r',label='regression')
plt.legend()

# predict
plt.subplot(212)
test_data['gas_used'].plot()
plt.plot(block_height_test,np.polyval(rg7,block_height_test),'r',label='predict')
plt.legend()

print(rg7)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3331: RankWarning: Polyfit may be poorly conditioned
#   exec(code_obj, self.user_global_ns, self.user_ns)
# [ 1.19307722e-32 -1.26863705e-25 -1.68044594e-19  2.88080473e-12
#   1.65130743e-05 -3.14637901e+01 -7.82231059e+08  2.41163373e+15]
