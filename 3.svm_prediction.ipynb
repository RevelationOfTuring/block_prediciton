# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns;sns.set()

# %%
# load data
hdf5=pd.HDFStore('data/block_data.h5','r')
training_data=hdf5['training_data']
test_data=hdf5['test_data']

# %%
# draw training data
threshold=30000000
training_data['gas_used'].plot(figsize=(50,20))
plt.axhline(threshold,color='r')

# %%
test_data
# Out:
#          gas_limit                                     guessed_miner  \
# height
# 5763555   42489312  exvaloper1s6nfs7mlj7ewsskkrmekqhpq2w234fcz5uq4m5
# 5763556   23678190  exvaloper19e6edpu97d6w2t5dlp7lph2fkdja0lvlj8ngk0
# 5763557   27402095  exvaloper1xkl5agjzqnjnptyat2dng2asmx8g5kllg7xamv
# 5763558   44549032  exvaloper1q9nct2gska2yutx24starv6s63xz022fdwdgzv
# 5763559   45312640  exvaloper1qva0ejf0t943x6rt824gwmvtjgec9cjrut5wn8
# ...            ...                                               ...
# 5794247  204003042  exvaloper19e6edpu97d6w2t5dlp7lph2fkdja0lvlj8ngk0
# 5794248  257298912  exvaloper1ygcvtcqxl82xvzrq25dymam434k3nnc8kwvrkm
# 5794249  299330975  exvaloper1s6nfs7mlj7ewsskkrmekqhpq2w234fcz5uq4m5
# 5794250  169903156  exvaloper1s6nfs7mlj7ewsskkrmekqhpq2w234fcz5uq4m5
# 5794251   87769690  exvaloper1qva0ejf0t943x6rt824gwmvtjgec9cjrut5wn8
#
#              blocktime  gas_used  txnum       区块耗时   elapsed-time  \
# height
# 5763555  1632489092000  13908388     74   56783000           4000
# 5763556  1632489096000   6273255     35   55534000           4000
# 5763557  1632489100000   5578559     29   48257000           4000
# 5763558  1632489104000  14745062     71 -232282000           4000
# 5763559  1632489108000  13679142     66  -33185000           4000
# ...                ...       ...    ...        ...            ...
# 5794247  1632622416000  50419352    200  -93207000           6000
# 5794248  1632622422000  47245075    200  -63630000          11000
# 5794249  1632622433000  76335761    300  -10928000          15000
# 5794250  1632622448000  33176916    187 -101723000           8000
# 5794251  1632622456000  11354989     81  -18688000 -1632622456000
#
#          gas used \n是否超过3千万\n1为超过，-1不超过
# height
# 5763555                            -1.0
# 5763556                            -1.0
# 5763557                            -1.0
# 5763558                            -1.0
# 5763559                            -1.0
# ...                                 ...
# 5794247                             1.0
# 5794248                             1.0
# 5794249                             1.0
# 5794250                             1.0
# 5794251                             NaN
#
# [30697 rows x 8 columns]
